# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Load and preprocess the MNIST dataset (replace with your Arabic numeral dataset)
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# Define the model architecture
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),  # Flatten the 28x28 images to a 1D array
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')  # Output layer with 10 neurons for 0-9 digits
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(train_images, train_labels, epochs=5)

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('\nTest accuracy:', test_acc)
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2913 - accuracy: 0.9160
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1409 - accuracy: 0.9580
# Epoch 3/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1048 - accuracy: 0.9678
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0869 - accuracy: 0.9732
# Epoch 5/5
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0751 - accuracy: 0.9782
#
# Test accuracy: 0.9782000184059143

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np

# Load and preprocess the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# Define the model architecture
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),  # Flatten the 28x28 images to a 1D array
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')  # Output layer with 10 neurons for 0-9 digits
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(train_images, train_labels, epochs=5)

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('\nTest accuracy:', test_acc)

# Visualize predictions on some random test images
num_images_to_plot = 5
random_indices = np.random.choice(len(test_images), num_images_to_plot, replace=False)

for index in random_indices:
    test_image = test_images[index]
    true_label = test_labels[index]

    # Reshape the image to match the model input shape
    test_image_reshaped = np.expand_dims(test_image, axis=0)

    # Get model prediction
    predictions = model.predict(test_image_reshaped)
    predicted_label = np.argmax(predictions)

    # Plot the image
    plt.imshow(test_image, cmap=plt.cm.binary)
    plt.title(f'True: {true_label}, Predicted: {predicted_label}')
    plt.show()
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2962 - accuracy: 0.9139
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1411 - accuracy: 0.9583
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1077 - accuracy: 0.9678
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0879 - accuracy: 0.9726
# Epoch 5/5
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0755 - accuracy: 0.9775
#
# Test accuracy: 0.9775000214576721
# ...
# 1/1 [==============================] - 0s 14ms/step
